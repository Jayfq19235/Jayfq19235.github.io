# %%
import pandas as pd
import requests

# %%
url = "https://en.wikipedia.org/wiki/List_of_best-selling_manga"

# %%
html = requests.get(url)

# %%
html
# Out:
# <Response [200]>

# %%
dfs = pd.read_html(url)

# %%
dfs[1]
# Out:
#                       Manga series  ... Average sales per volume[b]
# 0                        One Piece  ...                4.85 million
# 1                         Golgo 13  ...                1.49 million
# 2                      Dragon Ball  ...                6.19 million
# 3                           Naruto  ...                3.47 million
# 4                  Detective Conan  ...                2.50 million
# 5                         Doraemon  ...                3.77 million
# 6       KochiKame: Tokyo Beat Cops  ...                0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  ...                6.52 million
# 8                 Crayon Shin-chan  ...                2.55 million
# 9                         Oishinbo  ...                1.21 million
# 10                          Bleach  ...                1.62 million
# 11                       Slam Dunk  ...                3.87 million
# 12        JoJo's Bizarre Adventure  ...                0.91 million
# ...

# %%
df=dfs[1]

# %%
df.columns
# Out:
# Index(['Manga series', 'Author(s)', 'Publisher', 'Demographic',
#        'No. of collectedvolumes', 'Serialized', 'Approximate sales',
#        'Average sales per volume[b]'],
#       dtype='object')

# %%
df.sort_values(by="Average sales per volume[b]", ascending=False)
# Out:
#                       Manga series  ... Average sales per volume[b]
# 7   Demon Slayer: Kimetsu no Yaiba  ...                6.52 million
# 2                      Dragon Ball  ...                6.19 million
# 0                        One Piece  ...                4.85 million
# 13                       Astro Boy  ...                4.34 million
# 11                       Slam Dunk  ...                3.87 million
# 17                           Touch  ...                3.84 million
# 5                         Doraemon  ...                3.77 million
# 15          Fist of the North Star  ...                3.70 million
# 3                           Naruto  ...                3.47 million
# 14                 Attack on Titan  ...                2.94 million
# 8                 Crayon Shin-chan  ...                2.55 million
# 4                  Detective Conan  ...                2.50 million
# 10                          Bleach  ...                1.62 million
# ...

# %%
dfg = df.columns[0]

# %%
dfg
# Out:
# 'Manga series'

# %%
df.tail
# Out:
# <bound method NDFrame.tail of                       Manga series  ... Average sales per volume[b]
# 0                        One Piece  ...                4.85 million
# 1                         Golgo 13  ...                1.49 million
# 2                      Dragon Ball  ...                6.19 million
# 3                           Naruto  ...                3.47 million
# 4                  Detective Conan  ...                2.50 million
# 5                         Doraemon  ...                3.77 million
# 6       KochiKame: Tokyo Beat Cops  ...                0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  ...                6.52 million
# 8                 Crayon Shin-chan  ...                2.55 million
# 9                         Oishinbo  ...                1.21 million
# 10                          Bleach  ...                1.62 million
# 11                       Slam Dunk  ...                3.87 million
# ...

# %%
df["Approximate sales"].str.replace('million','')
# Out:
# 0        490 [2][d]
# 1           300 [3]
# 2     260 [4][e][f]
# 3       250 [11][g]
# 4       250 [12][i]
# 5          170 [13]
# 6     156.5 [14][j]
# 7          150 [15]
# 8       148 [k][16]
# 9          135 [17]
# 10      120 [18][l]
# 11      120 [19][m]
# 12      120 [20][n]
# 13         100 [21]
# 14         100 [22]
# 15      100 [23][o]
# 16         100 [24]
# 17         100 [25]
# Name: Approximate sales, dtype: object

# %%
df.columns[1]
# Out:
# 'Author(s)'

# %%
df.columns=['A','B','C','D','E','F','G','H']

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'H'], dtype='object')

# %%
df
# Out:
#                               name  ...             H
# 0                        One Piece  ...  4.85 million
# 1                         Golgo 13  ...  1.49 million
# 2                      Dragon Ball  ...  6.19 million
# 3                           Naruto  ...  3.47 million
# 4                  Detective Conan  ...  2.50 million
# 5                         Doraemon  ...  3.77 million
# 6       KochiKame: Tokyo Beat Cops  ...  0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  ...  6.52 million
# 8                 Crayon Shin-chan  ...  2.55 million
# 9                         Oishinbo  ...  1.21 million
# 10                          Bleach  ...  1.62 million
# 11                       Slam Dunk  ...  3.87 million
# 12        JoJo's Bizarre Adventure  ...  0.91 million
# 13                       Astro Boy  ...  4.34 million
# 14                 Attack on Titan  ...  2.94 million
# 15          Fist of the North Star  ...  3.70 million
# ...

# %%
df=df.rename(columns={'A':'name'})

# %%
df
# Out:
#                                  A  ...             H
# 0                        One Piece  ...  4.85 million
# 1                         Golgo 13  ...  1.49 million
# 2                      Dragon Ball  ...  6.19 million
# 3                           Naruto  ...  3.47 million
# 4                  Detective Conan  ...  2.50 million
# 5                         Doraemon  ...  3.77 million
# 6       KochiKame: Tokyo Beat Cops  ...  0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  ...  6.52 million
# 8                 Crayon Shin-chan  ...  2.55 million
# 9                         Oishinbo  ...  1.21 million
# 10                          Bleach  ...  1.62 million
# 11                       Slam Dunk  ...  3.87 million
# 12        JoJo's Bizarre Adventure  ...  0.91 million
# 13                       Astro Boy  ...  4.34 million
# 14                 Attack on Titan  ...  2.94 million
# 15          Fist of the North Star  ...  3.70 million
# ...

# %%
df.drop(df.columns[[1,2,3,4,5,6]], axis=1)
# Out:
#                               name             H
# 0                        One Piece  4.85 million
# 1                         Golgo 13  1.49 million
# 2                      Dragon Ball  6.19 million
# 3                           Naruto  3.47 million
# 4                  Detective Conan  2.50 million
# 5                         Doraemon  3.77 million
# 6       KochiKame: Tokyo Beat Cops  0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  6.52 million
# 8                 Crayon Shin-chan  2.55 million
# 9                         Oishinbo  1.21 million
# 10                          Bleach  1.62 million
# 11                       Slam Dunk  3.87 million
# 12        JoJo's Bizarre Adventure  0.91 million
# 13                       Astro Boy  4.34 million
# 14                 Attack on Titan  2.94 million
# 15          Fist of the North Star  3.70 million
# 16        The Kindaichi Case Files  1.14 million
# 17                           Touch  3.84 million

# %%
df = df.drop(df.columns[[1,2,3,4,5,6]], axis=1)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-27-97e656273265> in <module>()
# ----> 1 df = df.drop(df.columns[[1,2,3,4,5,6]], axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexes/base.py in __getitem__(self, key)
#    4112             key = np.asarray(key, dtype=bool)
#    4113
# -> 4114         result = getitem(key)
#    4115         if not is_scalar(result):
#    4116             if np.ndim(result) > 1:
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
df
# Out:
#                               name             H
# 0                        One Piece  4.85 million
# 1                         Golgo 13  1.49 million
# 2                      Dragon Ball  6.19 million
# 3                           Naruto  3.47 million
# 4                  Detective Conan  2.50 million
# 5                         Doraemon  3.77 million
# 6       KochiKame: Tokyo Beat Cops  0.77 million
# 7   Demon Slayer: Kimetsu no Yaiba  6.52 million
# 8                 Crayon Shin-chan  2.55 million
# 9                         Oishinbo  1.21 million
# 10                          Bleach  1.62 million
# 11                       Slam Dunk  3.87 million
# 12        JoJo's Bizarre Adventure  0.91 million
# 13                       Astro Boy  4.34 million
# 14                 Attack on Titan  2.94 million
# 15          Fist of the North Star  3.70 million
# 16        The Kindaichi Case Files  1.14 million
# 17                           Touch  3.84 million

# %%
df=df.sort_values(by='H', ascending=False)

# %%
df
# Out:
#                               name             H
# 7   Demon Slayer: Kimetsu no Yaiba  6.52 million
# 2                      Dragon Ball  6.19 million
# 0                        One Piece  4.85 million
# 13                       Astro Boy  4.34 million
# 11                       Slam Dunk  3.87 million
# 17                           Touch  3.84 million
# 5                         Doraemon  3.77 million
# 15          Fist of the North Star  3.70 million
# 3                           Naruto  3.47 million
# 14                 Attack on Titan  2.94 million
# 8                 Crayon Shin-chan  2.55 million
# 4                  Detective Conan  2.50 million
# 10                          Bleach  1.62 million
# 1                         Golgo 13  1.49 million
# 9                         Oishinbo  1.21 million
# 16        The Kindaichi Case Files  1.14 million
# 12        JoJo's Bizarre Adventure  0.91 million
# 6       KochiKame: Tokyo Beat Cops  0.77 million

# %%
df['H']=df['H'].str.replace('million','')

# %%
df
# Out:
#                               name      H
# 7   Demon Slayer: Kimetsu no Yaiba  6.52
# 2                      Dragon Ball  6.19
# 0                        One Piece  4.85
# 13                       Astro Boy  4.34
# 11                       Slam Dunk  3.87
# 17                           Touch  3.84
# 5                         Doraemon  3.77
# 15          Fist of the North Star  3.70
# 3                           Naruto  3.47
# 14                 Attack on Titan  2.94
# 8                 Crayon Shin-chan  2.55
# 4                  Detective Conan  2.50
# 10                          Bleach  1.62
# 1                         Golgo 13  1.49
# 9                         Oishinbo  1.21
# 16        The Kindaichi Case Files  1.14
# 12        JoJo's Bizarre Adventure  0.91
# 6       KochiKame: Tokyo Beat Cops  0.77

# %%
df.head(n=10)
# Out:
#                               name      H
# 7   Demon Slayer: Kimetsu no Yaiba  6.52
# 2                      Dragon Ball  6.19
# 0                        One Piece  4.85
# 13                       Astro Boy  4.34
# 11                       Slam Dunk  3.87
# 17                           Touch  3.84
# 5                         Doraemon  3.77
# 15          Fist of the North Star  3.70
# 3                           Naruto  3.47
# 14                 Attack on Titan  2.94

# %%
df=df.head(n=10)

# %%
df
# Out:
#                               name      H
# 7   Demon Slayer: Kimetsu no Yaiba  6.52
# 2                      Dragon Ball  6.19
# 0                        One Piece  4.85
# 13                       Astro Boy  4.34
# 11                       Slam Dunk  3.87
# 17                           Touch  3.84
# 5                         Doraemon  3.77
# 15          Fist of the North Star  3.70
# 3                           Naruto  3.47
# 14                 Attack on Titan  2.94

# %%
df.to_csv("manga_data.csv")

# %%
from google.colab import files

# %%
files.download("manga_data.csv")
